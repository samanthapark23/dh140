# %% [markdown]
# ## Hamlet

# %%
with open('data/Hamlet.txt') as f:
    x= f.read()

# %%
x
# Out:
# 'Hamlet\nby William Shakespeare\nEdited by Barbara A. Mowat and Paul Werstine\n  with Michael Poston and Rebecca Niles\nFolger Shakespeare Library\nhttps://shakespeare.folger.edu/shakespeares-works/hamlet/\nCreated on Jul 31, 2015, from FDT version 0.9.2\n\nCharacters in the Play\n======================\nTHE GHOST\nHAMLET, Prince of Denmark, son of the late King Hamlet and Queen Gertrude\nQUEEN GERTRUDE, widow of King Hamlet, now married to Claudius\nKING CLAUDIUS, brother to the late King Hamlet\nOPHELIA\nLAERTES, her brother\nPOLONIUS, father of Ophelia and Laertes, councillor to King Claudius\nREYNALDO, servant to Polonius\nHORATIO, Hamlet\'s friend and confidant\nCourtiers at the Danish court:\n  VOLTEMAND\n  CORNELIUS\n  ROSENCRANTZ\n  GUILDENSTERN\n  OSRIC\n  Gentlemen\n  A Lord\nDanish soldiers:\n  FRANCISCO\n  BARNARDO\n  MARCELLUS\nFORTINBRAS, Prince of Norway\nA Captain in Fortinbras\'s army\nAmbassadors to Denmark from England\nPlayers who take the roles of Prologue, Playe
# ...

# %%
x.split('ACT')[1].split('Scene')[1] #first scene
# Out:
# " 1\n=======\n[Enter Barnardo and Francisco, two sentinels.]\n\n\nBARNARDO  Who's there?\n\nFRANCISCO\nNay, answer me. Stand and unfold yourself.\n\nBARNARDO  Long live the King!\n\nFRANCISCO  Barnardo?\n\nBARNARDO  He.\n\nFRANCISCO\nYou come most carefully upon your hour.\n\nBARNARDO\n'Tis now struck twelve. Get thee to bed, Francisco.\n\nFRANCISCO\nFor this relief much thanks. 'Tis bitter cold,\nAnd I am sick at heart.\n\nBARNARDO  Have you had quiet guard?\n\nFRANCISCO  Not a mouse stirring.\n\nBARNARDO  Well, good night.\nIf you do meet Horatio and Marcellus,\nThe rivals of my watch, bid them make haste.\n\n[Enter Horatio and Marcellus.]\n\n\nFRANCISCO\nI think I hear them.--Stand ho! Who is there?\n\nHORATIO  Friends to this ground.\n\nMARCELLUS  And liegemen to the Dane.\n\nFRANCISCO  Give you good night.\n\nMARCELLUS\nO farewell, honest soldier. Who hath relieved\nyou?\n\nFRANCISCO\nBarnardo hath my place. Give you good night.\n[Francisco exits.]\n\nMARCELLUS  Holla, Barnardo.
# ...

# %%
acts = x.split('ACT')[1:]
acts
# Out:
# [' 1\n=====\n\nScene 1\n=======\n[Enter Barnardo and Francisco, two sentinels.]\n\n\nBARNARDO  Who\'s there?\n\nFRANCISCO\nNay, answer me. Stand and unfold yourself.\n\nBARNARDO  Long live the King!\n\nFRANCISCO  Barnardo?\n\nBARNARDO  He.\n\nFRANCISCO\nYou come most carefully upon your hour.\n\nBARNARDO\n\'Tis now struck twelve. Get thee to bed, Francisco.\n\nFRANCISCO\nFor this relief much thanks. \'Tis bitter cold,\nAnd I am sick at heart.\n\nBARNARDO  Have you had quiet guard?\n\nFRANCISCO  Not a mouse stirring.\n\nBARNARDO  Well, good night.\nIf you do meet Horatio and Marcellus,\nThe rivals of my watch, bid them make haste.\n\n[Enter Horatio and Marcellus.]\n\n\nFRANCISCO\nI think I hear them.--Stand ho! Who is there?\n\nHORATIO  Friends to this ground.\n\nMARCELLUS  And liegemen to the Dane.\n\nFRANCISCO  Give you good night.\n\nMARCELLUS\nO farewell, honest soldier. Who hath relieved\nyou?\n\nFRANCISCO\nBarnardo hath my place. Give you good night.\n[Francisco exits.]\n\nMARCE
# ...

# %%
acts[0].split('Scene')[-1] #act 1 last scene
# Out:
# ' 5\n=======\n[Enter Ghost and Hamlet.]\n\n\nHAMLET\nWhither wilt thou lead me? Speak. I\'ll go no\nfurther.\n\nGHOST\nMark me.\n\nHAMLET  I will.\n\nGHOST  My hour is almost come\nWhen I to sulf\'rous and tormenting flames\nMust render up myself.\n\nHAMLET  Alas, poor ghost!\n\nGHOST\nPity me not, but lend thy serious hearing\nTo what I shall unfold.\n\nHAMLET  Speak. I am bound to hear.\n\nGHOST\nSo art thou to revenge, when thou shalt hear.\n\nHAMLET  What?\n\nGHOST  I am thy father\'s spirit,\nDoomed for a certain term to walk the night\nAnd for the day confined to fast in fires\nTill the foul crimes done in my days of nature\nAre burnt and purged away. But that I am forbid\nTo tell the secrets of my prison house,\nI could a tale unfold whose lightest word\nWould harrow up thy soul, freeze thy young blood,\nMake thy two eyes, like stars, start from their\nspheres,\nThy knotted and combined locks to part,\nAnd each particular hair to stand an end,\nLike quills upon the fearful por
# ...

# %%
acts[0].split('Scene')[2].find('LAERTES') #as long as it's positive we know the character spoke in the scene; -1 means it doesn't occur
# Out:
# 2425

# %%
characters = [
    'GHOST',
    'HAMLET',
    'QUEEN',
    'KING',
    'OPHELIA',
    'LAERTES',
    'POLONIUS',
    'REYNALDO',
    'HORATIO',
    'VOLTEMAND',
    'CORNELIUS',
    'ROSENCRANTZ',
    'GUILDENSTERN',
    'OSRIC',
    'GENTLEMAN',
    'LORD',
    'FRANCISCO',
    'BARNARDO',
    'MARCELLUS',
    'FORTINBRAS',
    'CAPTAIN',
    'AMBASSADOR',
    'FIRST PLAYER',
    'PLAYER', #Players who take the roles of Prologue, Player King, Player Queen, and Lucianus in <title>The Murder of Gonzago</title>
    'MESSENGER',
    'SAILOR',
    'GRAVEDIGGER',
    'OTHER', #Gravedigger's companion
    'DOCTOR', #Doctor of Divinity
]

# %%
len(acts)
# Out:
# 5

# %%
len(characters)
# Out:
# 29

# %%
charnum = {}

connections = {}
for i in range(len(characters)-1):
    for j in range(i+1,len(characters)):
        connections[(characters[i],characters[j])] = 0

for k in characters:
    charnum[k] = 0

for i in acts:
    for j in i.split('Scene')[1:]:
        scenechars = []
        for k in characters:
            if j.find(k) != -1:
                scenechars.append(k)
                charnum[k] += 1
        for a in range(len(scenechars)-1):
            for b in range(a+1,len(scenechars)):
                connections[(scenechars[a],scenechars[b])] += 1

# %%
charnum #number of scenes they appear
# Out:
# {'GHOST': 2,
#  'HAMLET': 13,
#  'QUEEN': 10,
#  'KING': 11,
#  'OPHELIA': 5,
#  'LAERTES': 6,
#  'POLONIUS': 8,
#  'REYNALDO': 1,
#  'HORATIO': 9,
#  'VOLTEMAND': 2,
#  'CORNELIUS': 1,
#  'ROSENCRANTZ': 7,
#  'GUILDENSTERN': 5,
#  'OSRIC': 1,
#  'GENTLEMAN': 2,
#  'LORD': 1,
#  'FRANCISCO': 1,
#  'BARNARDO': 2,
#  'MARCELLUS': 4,
#  'FORTINBRAS': 2,
#  'CAPTAIN': 1,
#  'AMBASSADOR': 1,
#  'FIRST PLAYER': 1,
#  'PLAYER': 2,
#  'MESSENGER': 2,
#  'SAILOR': 1,
#  'GRAVEDIGGER': 1,
#  'OTHER': 1,
#  'DOCTOR': 1}

# %%
connections #number of scenes the characters occur together
# Out:
# {('GHOST', 'HAMLET'): 2,
#  ('GHOST', 'QUEEN'): 1,
#  ('GHOST', 'KING'): 0,
#  ('GHOST', 'OPHELIA'): 0,
#  ('GHOST', 'LAERTES'): 0,
#  ('GHOST', 'POLONIUS'): 1,
#  ('GHOST', 'REYNALDO'): 0,
#  ('GHOST', 'HORATIO'): 1,
#  ('GHOST', 'VOLTEMAND'): 0,
#  ('GHOST', 'CORNELIUS'): 0,
#  ('GHOST', 'ROSENCRANTZ'): 0,
#  ('GHOST', 'GUILDENSTERN'): 0,
#  ('GHOST', 'OSRIC'): 0,
#  ('GHOST', 'GENTLEMAN'): 0,
#  ('GHOST', 'LORD'): 0,
#  ('GHOST', 'FRANCISCO'): 0,
#  ('GHOST', 'BARNARDO'): 0,
#  ('GHOST', 'MARCELLUS'): 1,
#  ('GHOST', 'FORTINBRAS'): 0,
#  ('GHOST', 'CAPTAIN'): 0,
#  ('GHOST', 'AMBASSADOR'): 0,
#  ('GHOST', 'FIRST PLAYER'): 0,
#  ('GHOST', 'PLAYER'): 0,
#  ('GHOST', 'MESSENGER'): 0,
#  ('GHOST', 'SAILOR'): 0,
#  ('GHOST', 'GRAVEDIGGER'): 0,
#  ('GHOST', 'OTHER'): 0,
#  ('GHOST', 'DOCTOR'): 0,
#  ('HAMLET', 'QUEEN'): 7,
#  ('HAMLET', 'KING'): 8,
#  ('HAMLET', 'OPHELIA'): 2,
#  ('HAMLET', 'LAERTES'): 3,
#  ('HAMLET', 'POLONIUS'): 6,
#  ('HAMLET', 'REYNALDO'): 0,
# ...

# %%
for k,v in charnum.items():
    print(k,v)
# Out:
# GHOST 2
# HAMLET 13
# QUEEN 10
# KING 11
# OPHELIA 5
# LAERTES 6
# POLONIUS 8
# REYNALDO 1
# HORATIO 9
# VOLTEMAND 2
# CORNELIUS 1
# ROSENCRANTZ 7
# GUILDENSTERN 5
# OSRIC 1
# GENTLEMAN 2
# LORD 1
# FRANCISCO 1
# BARNARDO 2
# MARCELLUS 4
# FORTINBRAS 2
# CAPTAIN 1
# AMBASSADOR 1
# FIRST PLAYER 1
# PLAYER 2
# MESSENGER 2
# SAILOR 1
# GRAVEDIGGER 1
# OTHER 1
# DOCTOR 1

# %%
graphitems = []

for k,v in charnum.items():
    dashnode = {'data': {'id': k,
                         'label': k.title(),
                         'size': str(v)}}
    graphitems.append(dashnode)
    
graphitems
# Out:
# [{'data': {'id': 'GHOST', 'label': 'Ghost', 'size': '2'}},
#  {'data': {'id': 'HAMLET', 'label': 'Hamlet', 'size': '13'}},
#  {'data': {'id': 'QUEEN', 'label': 'Queen', 'size': '10'}},
#  {'data': {'id': 'KING', 'label': 'King', 'size': '11'}},
#  {'data': {'id': 'OPHELIA', 'label': 'Ophelia', 'size': '5'}},
#  {'data': {'id': 'LAERTES', 'label': 'Laertes', 'size': '6'}},
#  {'data': {'id': 'POLONIUS', 'label': 'Polonius', 'size': '8'}},
#  {'data': {'id': 'REYNALDO', 'label': 'Reynaldo', 'size': '1'}},
#  {'data': {'id': 'HORATIO', 'label': 'Horatio', 'size': '9'}},
#  {'data': {'id': 'VOLTEMAND', 'label': 'Voltemand', 'size': '2'}},
#  {'data': {'id': 'CORNELIUS', 'label': 'Cornelius', 'size': '1'}},
#  {'data': {'id': 'ROSENCRANTZ', 'label': 'Rosencrantz', 'size': '7'}},
#  {'data': {'id': 'GUILDENSTERN', 'label': 'Guildenstern', 'size': '5'}},
#  {'data': {'id': 'OSRIC', 'label': 'Osric', 'size': '1'}},
#  {'data': {'id': 'GENTLEMAN', 'label': 'Gentleman', 'size': '2'}},
# ...

# %%
graphitems = []

for k,v in charnum.items():
    dashnode = {'data': {'id': k,
                         'label': k.title(),
                         'size': str(v)}}
    graphitems.append(dashnode)

for k,v in connections.items():
    if v != 0:
        dashedge = {'data': {'source': k[0],
                             'target': k[1],
                             'weight': v}}
        graphitems.append(dashedge)
    
graphitems
# Out:
# [{'data': {'id': 'GHOST', 'label': 'Ghost', 'size': '2'}},
#  {'data': {'id': 'HAMLET', 'label': 'Hamlet', 'size': '13'}},
#  {'data': {'id': 'QUEEN', 'label': 'Queen', 'size': '10'}},
#  {'data': {'id': 'KING', 'label': 'King', 'size': '11'}},
#  {'data': {'id': 'OPHELIA', 'label': 'Ophelia', 'size': '5'}},
#  {'data': {'id': 'LAERTES', 'label': 'Laertes', 'size': '6'}},
#  {'data': {'id': 'POLONIUS', 'label': 'Polonius', 'size': '8'}},
#  {'data': {'id': 'REYNALDO', 'label': 'Reynaldo', 'size': '1'}},
#  {'data': {'id': 'HORATIO', 'label': 'Horatio', 'size': '9'}},
#  {'data': {'id': 'VOLTEMAND', 'label': 'Voltemand', 'size': '2'}},
#  {'data': {'id': 'CORNELIUS', 'label': 'Cornelius', 'size': '1'}},
#  {'data': {'id': 'ROSENCRANTZ', 'label': 'Rosencrantz', 'size': '7'}},
#  {'data': {'id': 'GUILDENSTERN', 'label': 'Guildenstern', 'size': '5'}},
#  {'data': {'id': 'OSRIC', 'label': 'Osric', 'size': '1'}},
#  {'data': {'id': 'GENTLEMAN', 'label': 'Gentleman', 'size': '2'}},
# ...

# %%
import dash
import dash_cytoscape as cyto
from dash import html, dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
from jupyter_dash.comms import _send_jupyter_config_comm_request

# %%
_send_jupyter_config_comm_request()

# %%
JupyterDash.infer_jupyter_proxy_config()

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    cyto.Cytoscape(
        layout={'name': 'cose'},
        elements=graphitems
    )
])

app.run_server(debug=True)
# Out:
# Dash app running on https://jupyter.idre.ucla.edu/user/samanthapark23@g.ucla.edu/proxy/8050/

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    cyto.Cytoscape(
        layout={'name': 'cose'},
        elements=graphitems,
        style={'width': '100%', 'height': '750px'},
    )
])

app.run_server(debug=True)
# Out:
# /opt/conda/lib/python3.9/site-packages/jupyter_dash/jupyter_app.py:139: UserWarning: The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.
#   func()
# Dash app running on https://jupyter.idre.ucla.edu/user/samanthapark23@g.ucla.edu/proxy/8050/

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    cyto.Cytoscape(
        layout={'name': 'cose'},
        elements=graphitems,
        style={'width': '100%', 'height': '750px'},
        stylesheet=[
            {
                'selector': 'node',
                'style': {
                    'content':'data(label)',
                    'text-halign':'center',
                    'text-valign':'center',
                    'width': 'data(size)',
                    'height': 'data(size)',
                    'font-size':4,
                    'color': 'blue',
                    'text-outline-color': 'white',
                    'text-outline-width': 0.2,
                    'shape':'circle'
                }
            },
            {
                'selector':'edge',
                'style': {
                    'width':'data(str(int(weight)/10))',
                    'line-color': 'orange',
                  }
            },
        ]
    )
])

app.run_server(debug=True)
# Out:
# Dash app running on https://jupyter.idre.ucla.edu/user/samanthapark23@g.ucla.edu/proxy/8050/

# %%
graphitems = []

for k,v in charnum.items():
    dashnode = {'data': {'id': k,
                         'label': k.title(),
                         'size': str(v)}}
    graphitems.append(dashnode)

correction_factor = max(connections.values())
print(correction_factor)
for k,v in connections.items():
    if v != 0:
        dashedge = {'data': {'source': k[0],
                             'target': k[1],
                             'weight': v/correction_factor}} #range from 0 to 1 
        graphitems.append(dashedge)
    
#graphitems
# Out:
# 9

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    cyto.Cytoscape(
        layout={'name': 'cose'},
        elements=graphitems,
        style={'width': '100%', 'height': '750px'},
        stylesheet=[
            {
                'selector': 'node',
                'style': {
                    'content':'data(label)',
                    'text-halign':'center',
                    'text-valign':'center',
                    'width': 'data(size)',
                    'height': 'data(size)',
                    'font-size':4,
                    'color': 'black',
                    'background-color': 'orange',
                    'text-outline-color': 'white',
                    'text-outline-width': 0.2,
                    'shape':'circle'
                }
            },
            {
                'selector':'edge',
                'style': {
                    'width':'data(weight)', #difference
                    'line-color': 'blue',
                  }
            },
        ]
    )
])

app.run_server(debug=True)
# Out:
# Dash app running on https://jupyter.idre.ucla.edu/user/samanthapark23@g.ucla.edu/proxy/8050/

# %%
graphitems
# Out:
# [{'data': {'id': 'GHOST', 'label': 'Ghost', 'size': '2'}},
#  {'data': {'id': 'HAMLET', 'label': 'Hamlet', 'size': '13'}},
#  {'data': {'id': 'QUEEN', 'label': 'Queen', 'size': '10'}},
#  {'data': {'id': 'KING', 'label': 'King', 'size': '11'}},
#  {'data': {'id': 'OPHELIA', 'label': 'Ophelia', 'size': '5'}},
#  {'data': {'id': 'LAERTES', 'label': 'Laertes', 'size': '6'}},
#  {'data': {'id': 'POLONIUS', 'label': 'Polonius', 'size': '8'}},
#  {'data': {'id': 'REYNALDO', 'label': 'Reynaldo', 'size': '1'}},
#  {'data': {'id': 'HORATIO', 'label': 'Horatio', 'size': '9'}},
#  {'data': {'id': 'VOLTEMAND', 'label': 'Voltemand', 'size': '2'}},
#  {'data': {'id': 'CORNELIUS', 'label': 'Cornelius', 'size': '1'}},
#  {'data': {'id': 'ROSENCRANTZ', 'label': 'Rosencrantz', 'size': '7'}},
#  {'data': {'id': 'GUILDENSTERN', 'label': 'Guildenstern', 'size': '5'}},
#  {'data': {'id': 'OSRIC', 'label': 'Osric', 'size': '1'}},
#  {'data': {'id': 'GENTLEMAN', 'label': 'Gentleman', 'size': '2'}},
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
nxgraphitems = []

# for k,v in charnum.items():
#     dashnode = k
#     graphitems.append(dashnode)

for k,v in connections.items():
    if v != 0:
        dashedge = (k[0],k[1])
        nxgraphitems.append(dashedge)
    
nxgraphitems
# Out:
# [('GHOST', 'HAMLET'),
#  ('GHOST', 'QUEEN'),
#  ('GHOST', 'POLONIUS'),
#  ('GHOST', 'HORATIO'),
#  ('GHOST', 'MARCELLUS'),
#  ('HAMLET', 'QUEEN'),
#  ('HAMLET', 'KING'),
#  ('HAMLET', 'OPHELIA'),
#  ('HAMLET', 'LAERTES'),
#  ('HAMLET', 'POLONIUS'),
#  ('HAMLET', 'HORATIO'),
#  ('HAMLET', 'VOLTEMAND'),
#  ('HAMLET', 'CORNELIUS'),
#  ('HAMLET', 'ROSENCRANTZ'),
#  ('HAMLET', 'GUILDENSTERN'),
#  ('HAMLET', 'OSRIC'),
#  ('HAMLET', 'LORD'),
#  ('HAMLET', 'BARNARDO'),
#  ('HAMLET', 'MARCELLUS'),
#  ('HAMLET', 'FORTINBRAS'),
#  ('HAMLET', 'CAPTAIN'),
#  ('HAMLET', 'AMBASSADOR'),
#  ('HAMLET', 'FIRST PLAYER'),
#  ('HAMLET', 'PLAYER'),
#  ('HAMLET', 'GRAVEDIGGER'),
#  ('HAMLET', 'OTHER'),
#  ('HAMLET', 'DOCTOR'),
#  ('QUEEN', 'KING'),
#  ('QUEEN', 'OPHELIA'),
#  ('QUEEN', 'LAERTES'),
#  ('QUEEN', 'POLONIUS'),
#  ('QUEEN', 'HORATIO'),
#  ('QUEEN', 'VOLTEMAND'),
#  ('QUEEN', 'CORNELIUS'),
#  ('QUEEN', 'ROSENCRANTZ'),
#  ('QUEEN', 'GUILDENSTERN'),
#  ('QUEEN', 'OSRIC'),
# ...

# %%
G = nx.Graph()

# %%
G.add_edges_from(nxgraphitems)

# %%
G.nodes
# Out:
# NodeView(('GHOST', 'HAMLET', 'QUEEN', 'POLONIUS', 'HORATIO', 'MARCELLUS', 'KING', 'OPHELIA', 'LAERTES', 'VOLTEMAND', 'CORNELIUS', 'ROSENCRANTZ', 'GUILDENSTERN', 'OSRIC', 'LORD', 'BARNARDO', 'FORTINBRAS', 'CAPTAIN', 'AMBASSADOR', 'FIRST PLAYER', 'PLAYER', 'GRAVEDIGGER', 'OTHER', 'DOCTOR', 'GENTLEMAN', 'MESSENGER', 'REYNALDO', 'FRANCISCO', 'SAILOR'))

# %%
nx.degree_centrality(G)
# Out:
# {'GHOST': 0.17857142857142855,
#  'HAMLET': 0.8214285714285714,
#  'QUEEN': 0.8571428571428571,
#  'POLONIUS': 0.5714285714285714,
#  'HORATIO': 0.8928571428571428,
#  'MARCELLUS': 0.39285714285714285,
#  'KING': 0.8214285714285714,
#  'OPHELIA': 0.42857142857142855,
#  'LAERTES': 0.6785714285714285,
#  'VOLTEMAND': 0.46428571428571425,
#  'CORNELIUS': 0.3214285714285714,
#  'ROSENCRANTZ': 0.42857142857142855,
#  'GUILDENSTERN': 0.3571428571428571,
#  'OSRIC': 0.2857142857142857,
#  'LORD': 0.2857142857142857,
#  'BARNARDO': 0.3571428571428571,
#  'FORTINBRAS': 0.3571428571428571,
#  'CAPTAIN': 0.10714285714285714,
#  'AMBASSADOR': 0.2857142857142857,
#  'FIRST PLAYER': 0.2857142857142857,
#  'PLAYER': 0.3571428571428571,
#  'GRAVEDIGGER': 0.25,
#  'OTHER': 0.25,
#  'DOCTOR': 0.25,
#  'GENTLEMAN': 0.25,
#  'MESSENGER': 0.21428571428571427,
#  'REYNALDO': 0.07142857142857142,
#  'FRANCISCO': 0.10714285714285714,
#  'SAILOR': 0.07142857142857142}

# %%
dc = nx.degree_centrality(G)
for i in sorted(dc, key=dc.get, reverse=True):
    print('{:15s}: {:.3f}'.format(i.title(), dc[i]))
# Out:
# Horatio        : 0.893
# Queen          : 0.857
# Hamlet         : 0.821
# King           : 0.821
# Laertes        : 0.679
# Polonius       : 0.571
# Voltemand      : 0.464
# Ophelia        : 0.429
# Rosencrantz    : 0.429
# Marcellus      : 0.393
# Guildenstern   : 0.357
# Barnardo       : 0.357
# Fortinbras     : 0.357
# Player         : 0.357
# Cornelius      : 0.321
# Osric          : 0.286
# Lord           : 0.286
# Ambassador     : 0.286
# First Player   : 0.286
# Gravedigger    : 0.250
# Other          : 0.250
# Doctor         : 0.250
# Gentleman      : 0.250
# Messenger      : 0.214
# Ghost          : 0.179
# Captain        : 0.107
# Francisco      : 0.107
# Reynaldo       : 0.071
# Sailor         : 0.071

# %%
list(G.neighbors('OTHER')) #list of characters who has speaking roles with OTHER
# Out:
# ['HAMLET', 'QUEEN', 'KING', 'LAERTES', 'HORATIO', 'GRAVEDIGGER', 'DOCTOR']

# %%
nx.betweenness_centrality(G)
# Out:
# {'GHOST': 0.0,
#  'HAMLET': 0.11320700169906521,
#  'QUEEN': 0.10040005555878571,
#  'POLONIUS': 0.056277819769883254,
#  'HORATIO': 0.19385663572171505,
#  'MARCELLUS': 0.012066431510875953,
#  'KING': 0.08540887390093738,
#  'OPHELIA': 0.03686527317479698,
#  'LAERTES': 0.05101976213087324,
#  'VOLTEMAND': 0.008207357016880827,
#  'CORNELIUS': 0.0,
#  'ROSENCRANTZ': 0.019841027579122816,
#  'GUILDENSTERN': 0.00141408415217939,
#  'OSRIC': 0.0,
#  'LORD': 0.0,
#  'BARNARDO': 0.008098177542621985,
#  'FORTINBRAS': 0.012893433726767059,
#  'CAPTAIN': 0.0,
#  'AMBASSADOR': 0.0,
#  'FIRST PLAYER': 0.0,
#  'PLAYER': 0.00141408415217939,
#  'GRAVEDIGGER': 0.0,
#  'OTHER': 0.0,
#  'DOCTOR': 0.0,
#  'GENTLEMAN': 0.00802469135802469,
#  'MESSENGER': 0.0,
#  'REYNALDO': 0.0,
#  'FRANCISCO': 0.0,
#  'SAILOR': 0.0}

# %%
dc = nx.betweenness_centrality(G)
for i in sorted(dc, key=dc.get, reverse=True):
    print('{:15s}: {:.3f}'.format(i.title(), dc[i]))
# Out:
# Horatio        : 0.194
# Hamlet         : 0.113
# Queen          : 0.100
# King           : 0.085
# Polonius       : 0.056
# Laertes        : 0.051
# Ophelia        : 0.037
# Rosencrantz    : 0.020
# Fortinbras     : 0.013
# Marcellus      : 0.012
# Voltemand      : 0.008
# Barnardo       : 0.008
# Gentleman      : 0.008
# Guildenstern   : 0.001
# Player         : 0.001
# Ghost          : 0.000
# Cornelius      : 0.000
# Osric          : 0.000
# Lord           : 0.000
# Captain        : 0.000
# Ambassador     : 0.000
# First Player   : 0.000
# Gravedigger    : 0.000
# Other          : 0.000
# Doctor         : 0.000
# Messenger      : 0.000
# Reynaldo       : 0.000
# Francisco      : 0.000
# Sailor         : 0.000

# %%
from networkx.algorithms.community.centrality import girvan_newman

# %% [markdown]
# nodes are characters and edges are determined based on characters having speaking roles in the same scene

# %%
communities = girvan_newman(G)

# %%
node_groups = []
for com in next(communities):
    node_groups.append(list(com))
 
print(node_groups)
 
color_map = []
for node in G:
    if node in node_groups[0]:
        color_map.append('blue')
    else:
        color_map.append('green')
nx.draw(G, node_color=color_map, with_labels=True)
plt.show()
# Out:
# [['POLONIUS', 'PLAYER', 'CORNELIUS', 'AMBASSADOR', 'LORD', 'MARCELLUS', 'OTHER', 'REYNALDO', 'ROSENCRANTZ', 'QUEEN', 'OSRIC', 'GUILDENSTERN', 'CAPTAIN', 'KING', 'VOLTEMAND', 'FRANCISCO', 'FIRST PLAYER', 'FORTINBRAS', 'HAMLET', 'OPHELIA', 'MESSENGER', 'DOCTOR', 'GRAVEDIGGER', 'LAERTES', 'GENTLEMAN', 'HORATIO', 'GHOST', 'BARNARDO'], ['SAILOR']]

# %%
nx.density(G) #third of the connections that it could have relative to the maximum number of connections that exist
# Out:
# 0.3793103448275862

# %%
from networkx.algorithms.community import greedy_modularity_communities

# %%
greedy_modularity_communities(G)
# Out:
# [frozenset({'BARNARDO',
#             'CORNELIUS',
#             'FRANCISCO',
#             'GHOST',
#             'LAERTES',
#             'MARCELLUS',
#             'POLONIUS',
#             'VOLTEMAND'}),
#  frozenset({'AMBASSADOR',
#             'CAPTAIN',
#             'FORTINBRAS',
#             'HAMLET',
#             'LORD',
#             'OSRIC',
#             'ROSENCRANTZ'}),
#  frozenset({'GENTLEMAN',
#             'HORATIO',
#             'MESSENGER',
#             'OPHELIA',
#             'REYNALDO',
#             'SAILOR'}),
#  frozenset({'FIRST PLAYER', 'GUILDENSTERN', 'PLAYER', 'QUEEN'}),
#  frozenset({'DOCTOR', 'GRAVEDIGGER', 'KING', 'OTHER'})]

# %% [markdown]
# Find communities in G using greedy modularity maximization.

# %%
communities = greedy_modularity_communities(G)
# Create empty dictionary
modularity_class = {}
#Loop through each community in the network
for community_number, community in enumerate(communities):
    #For each member of the community, add their community number
    for name in community:
        modularity_class[name] = community_number

# %%
modularity_class
# Out:
# {'POLONIUS': 0,
#  'VOLTEMAND': 0,
#  'LAERTES': 0,
#  'FRANCISCO': 0,
#  'CORNELIUS': 0,
#  'GHOST': 0,
#  'MARCELLUS': 0,
#  'BARNARDO': 0,
#  'ROSENCRANTZ': 1,
#  'AMBASSADOR': 1,
#  'FORTINBRAS': 1,
#  'HAMLET': 1,
#  'OSRIC': 1,
#  'LORD': 1,
#  'CAPTAIN': 1,
#  'GENTLEMAN': 2,
#  'HORATIO': 2,
#  'OPHELIA': 2,
#  'MESSENGER': 2,
#  'SAILOR': 2,
#  'REYNALDO': 2,
#  'FIRST PLAYER': 3,
#  'PLAYER': 3,
#  'GUILDENSTERN': 3,
#  'QUEEN': 3,
#  'DOCTOR': 4,
#  'OTHER': 4,
#  'GRAVEDIGGER': 4,
#  'KING': 4}

# %%
communities = greedy_modularity_communities(G)

node_groups = []
for com in communities:
    node_groups.append(list(com))
 
print(node_groups)
 
color_map = []
for node in G:
    if node in node_groups[0]:
        color_map.append('blue')
    elif node in node_groups[1]:
        color_map.append('yellow')
    else:
        color_map.append('green')
nx.draw(G, node_color=color_map, with_labels=True)
plt.show()
# Out:
# [['POLONIUS', 'VOLTEMAND', 'LAERTES', 'FRANCISCO', 'CORNELIUS', 'GHOST', 'MARCELLUS', 'BARNARDO'], ['ROSENCRANTZ', 'AMBASSADOR', 'FORTINBRAS', 'HAMLET', 'OSRIC', 'LORD', 'CAPTAIN'], ['GENTLEMAN', 'HORATIO', 'OPHELIA', 'MESSENGER', 'SAILOR', 'REYNALDO'], ['FIRST PLAYER', 'PLAYER', 'GUILDENSTERN', 'QUEEN'], ['DOCTOR', 'OTHER', 'GRAVEDIGGER', 'KING']]

# %%
graphitems = []

for k,v in charnum.items():
    if k in node_groups[0]:
        modularity = 'yellow'
    elif k in node_groups[1]:
        modularity = 'orange'
    else:
        modularity = 'blue'
    dashnode = {'data': {'id': k,
                         'label': k.title(),
                         'size': str(v),'modularity': modularity}}
    graphitems.append(dashnode)

correction_factor = max(connections.values())
print(correction_factor)
for k,v in connections.items():
    if v != 0:
        dashedge = {'data': {'source': k[0],
                             'target': k[1],
                             'weight': v/correction_factor}}
        graphitems.append(dashedge)
    
graphitems
# Out:
# 9
# [{'data': {'id': 'GHOST',
#    'label': 'Ghost',
#    'size': '2',
#    'modularity': 'yellow'}},
#  {'data': {'id': 'HAMLET',
#    'label': 'Hamlet',
#    'size': '13',
#    'modularity': 'orange'}},
#  {'data': {'id': 'QUEEN',
#    'label': 'Queen',
#    'size': '10',
#    'modularity': 'blue'}},
#  {'data': {'id': 'KING', 'label': 'King', 'size': '11', 'modularity': 'blue'}},
#  {'data': {'id': 'OPHELIA',
#    'label': 'Ophelia',
#    'size': '5',
#    'modularity': 'blue'}},
#  {'data': {'id': 'LAERTES',
#    'label': 'Laertes',
#    'size': '6',
#    'modularity': 'yellow'}},
#  {'data': {'id': 'POLONIUS',
#    'label': 'Polonius',
#    'size': '8',
#    'modularity': 'yellow'}},
#  {'data': {'id': 'REYNALDO',
#    'label': 'Reynaldo',
#    'size': '1',
#    'modularity': 'blue'}},
#  {'data': {'id': 'HORATIO',
#    'label': 'Horatio',
#    'size': '9',
#    'modularity': 'blue'}},
#  {'data': {'id': 'VOLTEMAND',
#    'label': 'Voltemand',
#    'size': '2',
# ...

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    cyto.Cytoscape(
        layout={'name': 'cose'},
        elements=graphitems,
        style={'width': '100%', 'height': '750px'},
        stylesheet=[
            {
                'selector': 'node',
                'style': {
                    'content':'data(label)',
                    'text-halign':'center',
                    'text-valign':'center',
                    'width': 'data(size)',
                    'height': 'data(size)',
                    'font-size': 4,
                    'color': 'black',
                    'background-color': 'data(modularity)',
                    'text-outline-color': 'white',
                    'text-outline-width': 0.2,
                    'shape':'square'
                }
            },
            {
                'selector':'edge',
                'style': {
                    'width':'data(weight)',
                    'line-color': 'blue',
                  }
            },
        ]
    )
])

app.run_server(debug=True)
# Out:
# Dash app running on https://jupyter.idre.ucla.edu/user/samanthapark23@g.ucla.edu/proxy/8050/
# /opt/conda/lib/python3.9/site-packages/jupyter_dash/jupyter_app.py:139: UserWarning: The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.
#   func()

# %% [markdown]
# The graph contains information regarding the relationships between characters and presence of each character appearing in Hamlet. The relationships were quantified by identifying the number of scenes the characters spoke to each other, which translated to the thickness of the edges. The bigger the square, the character has more presence in the play. This was quantified by the number of scenes in which the character speaks. The colors of the squares signify their communities.

# %% [markdown]
# The network's density is .379, and the most noticeable nodes are Hamlet, King, Queen, Horatio, Rosencrantz, and Polonius. They are most important as they are characters who come out in the play most frequently. (Hamlet = 13, King = 11 , Horatio = 9, Rosencrantz = 7, Polonius = 8, Queen = 10). Additionally, the edges between each other were thicker than those of other characters, meaning they had numerous speaking scenes with each other. (King & Queen = 9, King & Hamlet = 8, Hamlet & Horatio = 6, Hamlet & Queen = 7, Hamlet & Polonius = 6)
