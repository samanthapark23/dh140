# %% [markdown]
# #### Tokenize the words, remove stopwords, stem or lemmatize the words, and calculate the word frequencies

# %%
import nltk

# %%
import requests

# %%
response = requests.get('http://shakespeare.mit.edu/hamlet/full.html')

# %%
response
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup

# %%
html_string = response.text

# %%
html_string
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN"\n "http://www.w3.org/TR/REC-html40/loose.dtd">\n <html>\n <head>\n <title>Hamlet: Entire Play\n </title>\n <meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">\n <LINK rel="stylesheet" type="text/css" media="screen"\n       href="/shake.css">\n </HEAD>\n <body bgcolor="#ffffff" text="#000000">\n\n<table width="100%" bgcolor="#CCF6F6">\n<tr><td class="play" align="center">The Tragedy of Hamlet, Prince of Denmark\n<tr><td class="nav" align="center">\n      <a href="/Shakespeare">Shakespeare homepage</A> \n    | <A href="/hamlet/">Hamlet</A> \n    | Entire play\n</table>\n\n<H3>ACT I</h3>\n<h3>SCENE I. Elsinore. A platform before the castle.</h3>\n<p><blockquote>\n<i>FRANCISCO at his post. Enter to him BERNARDO</i>\n</blockquote>\n\n<A NAME=speech1><b>BERNARDO</b></a>\n<blockquote>\n<A NAME=1.1.1>Who\'s there?</A><br>\n</blockquote>\n\n<A NAME=speech2><b>FRANCISCO</b></a>\n<blockquote>\n<A NAME=1.1.2>Nay,
# ...

# %%
document = BeautifulSoup(html_string, "html.parser")

# %%
document
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN"
#  "http://www.w3.org/TR/REC-html40/loose.dtd">
#
# <html>
# <head>
# <title>Hamlet: Entire Play
#  </title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/shake.css" media="screen" rel="stylesheet" type="text/css"/>
# </head>
# <body bgcolor="#ffffff" text="#000000">
# <table bgcolor="#CCF6F6" width="100%">
# <tr><td align="center" class="play">The Tragedy of Hamlet, Prince of Denmark
# <tr><td align="center" class="nav">
# <a href="/Shakespeare">Shakespeare homepage</a>
#     | <a href="/hamlet/">Hamlet</a>
#     | Entire play
# </td></tr></td></tr></table>
# <h3>ACT I</h3>
# <h3>SCENE I. Elsinore. A platform before the castle.</h3>
# <p><blockquote>
# <i>FRANCISCO at his post. Enter to him BERNARDO</i>
# </blockquote>
# <a name="speech1"><b>BERNARDO</b></a>
# <blockquote>
# <a name="1.1.1">Who's there?</a><br/>
# </blockquote>
# <a name="speech2"><b>FRANCISCO</b></a>
# ...

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
hamlet = document.text

# %%
for i in ['\n','[',']','’','”','“']:
    hamlet = hamlet.replace(i,' ')

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation

# %%
words = word_tokenize(hamlet.lower())

# %%
words
# Out:
# ['hamlet',
#  ':',
#  'entire',
#  'play',
#  'the',
#  'tragedy',
#  'of',
#  'hamlet',
#  ',',
#  'prince',
#  'of',
#  'denmark',
#  'shakespeare',
#  'homepage',
#  '|',
#  'hamlet',
#  '|',
#  'entire',
#  'play',
#  'act',
#  'i',
#  'scene',
#  'i.',
#  'elsinore',
#  '.',
#  'a',
#  'platform',
#  'before',
#  'the',
#  'castle',
#  '.',
#  'francisco',
#  'at',
#  'his',
#  'post',
#  '.',
#  'enter',
#  'to',
#  'him',
#  'bernardo',
#  'bernardo',
#  'who',
#  "'s",
#  'there',
#  '?',
#  'francisco',
#  'nay',
#  ',',
#  'answer',
#  'me',
#  ':',
#  'stand',
#  ',',
#  'and',
#  'unfold',
#  'yourself',
#  '.',
#  'bernardo',
#  'long',
#  'live',
#  'the',
#  'king',
#  '!',
#  'francisco',
#  'bernardo',
#  '?',
#  'bernardo',
#  'he',
#  '.',
#  'francisco',
#  'you',
#  'come',
#  'most',
#  'carefully',
#  'upon',
#  'your',
#  'hour',
#  '.',
#  'bernardo',
#  "'t",
#  'is',
#  'now',
#  'struck',
#  'twelve',
#  ';',
#  'get',
#  'thee',
#  'to',
#  'bed',
# ...

# %%
extrastop = ['``',"''","'re","'s","'re",'``',"''","'ll","--","\'\'","...",
             "n\'t",'one','would','use','subject','from',"\'m","\'ve","i.","'d", "'t"]

# %%
myStopWords = list(punctuation) + stopwords.words('english') + extrastop

# %%
wordsNoStopWords = [w for w in words if w not in myStopWords]
wordsNoStopWords
# Out:
# ['hamlet',
#  'entire',
#  'play',
#  'tragedy',
#  'hamlet',
#  'prince',
#  'denmark',
#  'shakespeare',
#  'homepage',
#  'hamlet',
#  'entire',
#  'play',
#  'act',
#  'scene',
#  'elsinore',
#  'platform',
#  'castle',
#  'francisco',
#  'post',
#  'enter',
#  'bernardo',
#  'bernardo',
#  'francisco',
#  'nay',
#  'answer',
#  'stand',
#  'unfold',
#  'bernardo',
#  'long',
#  'live',
#  'king',
#  'francisco',
#  'bernardo',
#  'bernardo',
#  'francisco',
#  'come',
#  'carefully',
#  'upon',
#  'hour',
#  'bernardo',
#  'struck',
#  'twelve',
#  'get',
#  'thee',
#  'bed',
#  'francisco',
#  'francisco',
#  'relief',
#  'much',
#  'thanks',
#  'bitter',
#  'cold',
#  'sick',
#  'heart',
#  'bernardo',
#  'quiet',
#  'guard',
#  'francisco',
#  'mouse',
#  'stirring',
#  'bernardo',
#  'well',
#  'good',
#  'night',
#  'meet',
#  'horatio',
#  'marcellus',
#  'rivals',
#  'watch',
#  'bid',
#  'make',
#  'haste',
#  'francisco',
#  'think',
#  'hear',
#  'stand',
#  'ho',
# ...

# %%
[w for w in word_tokenize(wordsNoStopWords[0].lower()) if w not in myStopWords]
# Out:
# ['hamlet']

# %%
listOfNewsWords = []
for i in wordsNoStopWords:
    listOfNewsWords.append([w for w in word_tokenize(i.lower()) if w not in myStopWords])

# %%
listOfNewsWords[0]
# Out:
# ['hamlet']

# %%
from nltk.stem.porter import PorterStemmer

# %%
p_stemmer = PorterStemmer()

# %%
listOfStemmedWords = []
for i in listOfNewsWords:
    listOfStemmedWords.append([p_stemmer.stem(w) for w in i])

# %%
listOfStemmedWords
# Out:
# [['hamlet'],
#  ['entir'],
#  ['play'],
#  ['tragedi'],
#  ['hamlet'],
#  ['princ'],
#  ['denmark'],
#  ['shakespear'],
#  ['homepag'],
#  ['hamlet'],
#  ['entir'],
#  ['play'],
#  ['act'],
#  ['scene'],
#  ['elsinor'],
#  ['platform'],
#  ['castl'],
#  ['francisco'],
#  ['post'],
#  ['enter'],
#  ['bernardo'],
#  ['bernardo'],
#  ['francisco'],
#  ['nay'],
#  ['answer'],
#  ['stand'],
#  ['unfold'],
#  ['bernardo'],
#  ['long'],
#  ['live'],
#  ['king'],
#  ['francisco'],
#  ['bernardo'],
#  ['bernardo'],
#  ['francisco'],
#  ['come'],
#  ['care'],
#  ['upon'],
#  ['hour'],
#  ['bernardo'],
#  ['struck'],
#  ['twelv'],
#  ['get'],
#  ['thee'],
#  ['bed'],
#  ['francisco'],
#  ['francisco'],
#  ['relief'],
#  ['much'],
#  ['thank'],
#  ['bitter'],
#  ['cold'],
#  ['sick'],
#  ['heart'],
#  ['bernardo'],
#  ['quiet'],
#  ['guard'],
#  ['francisco'],
#  ['mous'],
#  ['stir'],
#  ['bernardo'],
#  ['well'],
#  ['good'],
#  ['night'],
#  ['meet'],
#  ['horatio'],
#  ['marcellu'],
# ...

# %%
from nltk.probability import FreqDist

# %%
freq = FreqDist(wordsNoStopWords)

# %%
freq
# Out:
# FreqDist({'hamlet': 471, 'lord': 310, 'king': 202, 'horatio': 157, 'claudius': 120, 'queen': 119, 'polonius': 119, 'shall': 114, 'good': 107, 'come': 106, ...})

# %%
type(freq)
# Out:
# nltk.probability.FreqDist

# %%
import pandas as pd

# %%
hamletdf = pd.DataFrame(list(freq.items()), columns = ["Word","Frequency"]) 
hamletdf
# Out:
#          Word  Frequency
# 0      hamlet        471
# 1      entire          2
# 2        play         43
# 3     tragedy          3
# 4      prince         10
# ...       ...        ...
# 4527   loudly          1
# 4528    field          1
# 4529    shoot          1
# 4530  bearing          1
# 4531     peal          1
#
# [4532 rows x 2 columns]

# %% [markdown]
# #### For the word frequencies, calculate the mean, median, mode, and trimmed mean.

# %%
hamletdf.describe()
# Out:
#          Frequency
# count  4532.000000
# mean      3.596425
# std      12.335153
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.000000
# max     471.000000

# %% [markdown]
# mean: 3.6

# %%
hamletdf["Frequency"].median()
# Out:
# 1.0

# %%
hamletdf["Frequency"].mode()
# Out:
# 0    1
# dtype: int64

# %%
sortedhamlet = hamletdf.sort_values(by='Frequency').copy()

# %%
sortedhamlet
# Out:
#              Word  Frequency
# 4531         peal          1
# 2584   resolution          1
# 2585     sicklied          1
# 2586  enterprises          1
# 2589         awry          1
# ...           ...        ...
# 470      claudius        120
# 48        horatio        157
# 23           king        202
# 585          lord        310
# 0          hamlet        471
#
# [4532 rows x 2 columns]

# %%
sortedhamlet = hamletdf.sort_values(by='Frequency',ignore_index=True).copy()

# %%
sortedhamlet
# Out:
#              Word  Frequency
# 0            peal          1
# 1      resolution          1
# 2        sicklied          1
# 3     enterprises          1
# 4            awry          1
# ...           ...        ...
# 4527     claudius        120
# 4528      horatio        157
# 4529         king        202
# 4530         lord        310
# 4531       hamlet        471
#
# [4532 rows x 2 columns]

# %%
sortedhamlet["Frequency"]
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#        ...
# 4527    120
# 4528    157
# 4529    202
# 4530    310
# 4531    471
# Name: Frequency, Length: 4532, dtype: int64

# %%
sortedhamlet.loc[int(0.1*4532):int(0.9*4532),'Frequency'].mean() #trimmed mean
# Out:
# 1.6798124655267512

# %% [markdown]
# I trimmed the lowest 10% of the list of words and the highest 10% of the list of words after sorting the words by frequency. This means the lowest 10% of list has the lowest frequencies and the highest 10% of list has the highest frequencies. The trimmed mean is closer to the median.

# %% [markdown]
# #### Plot a histogram of the word frequency data and comment on the relative locations of the mean, median, mode, and trimmed mean

# %%
hamletdf['Frequency'].plot(kind='hist', bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# This distribution is heavily skewed to the right.

# %%
print('Mean: ',hamletdf['Frequency'].mean())
print('Median: ',hamletdf['Frequency'].median())
print('Mode: ',hamletdf['Frequency'].mode())
# Out:
# Mean:  3.596425419240953
# Median:  1.0
# Mode:  0    1
# dtype: int64

# %% [markdown]
# The distribution is skewed to the right. The mean is more to the right of the median. The trimmed mean of 1.68 is closer to the median. Mode is  the same as the median.

# %% [markdown]
# #### Calculate the standard deviation and the interquartile range (the difference of the 75% and 25% quantile)

# %%
hamletdf["Frequency"].std()
# Out:
# 12.335153252330755

# %%
hamletdf['Frequency'].quantile(0.75)-hamletdf['Frequency'].quantile(0.25)
# Out:
# 1.0

# %% [markdown]
# ### Machine Learning

# %%
from sklearn import datasets
df = datasets.load_diabetes(as_frame=True) 
features_df = df.data
target_df = df.target

# %%
print(df.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
target_df.describe()
# Out:
# count    442.000000
# mean     152.133484
# std       77.093005
# min       25.000000
# 25%       87.000000
# 50%      140.500000
# 75%      211.500000
# max      346.000000
# Name: target, dtype: float64

# %%
features_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
features_df['target'] = target_df #added a target column to the features_df

# %%
features_df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %% [markdown]
# #### Find the column in features_df that has the highest correlation coefficient with the target values in target_df

# %%
features_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='object')

# %%
for i in features_df.columns:
    print (features_df[[i, 'target']].corr())
# Out:
#              age    target
# age     1.000000  0.187889
# target  0.187889  1.000000
#              sex    target
# sex     1.000000  0.043062
# target  0.043062  1.000000
#             bmi   target
# bmi     1.00000  0.58645
# target  0.58645  1.00000
#               bp    target
# bp      1.000000  0.441484
# target  0.441484  1.000000
#               s1    target
# s1      1.000000  0.212022
# target  0.212022  1.000000
#               s2    target
# s2      1.000000  0.174054
# target  0.174054  1.000000
#               s3    target
# s3      1.000000 -0.394789
# target -0.394789  1.000000
#               s4    target
# s4      1.000000  0.430453
# target  0.430453  1.000000
#               s5    target
# s5      1.000000  0.565883
# target  0.565883  1.000000
#               s6    target
# s6      1.000000  0.382483
# target  0.382483  1.000000
#         target  target
# target     1.0     1.0
# target     1.0     1.0

# %% [markdown]
# BMI has the highest correlation with the target values in target_df.

# %% [markdown]
# #### Make a scatter plot of the target values vs this feature column's values and comment on how the plotted points match up with the correlation coefficient

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
features_df.plot(kind='scatter',
        x='bmi',
        y='target');

# %% [markdown]
# The plotted points match up with the correlation coefficient of 0.59 as they show a somewhat strong positive trend.

# %% [markdown]
# #### Using this feature and target, perform linear regression with sklearn's LinearRegression. Print the coefficients of the model. Plot the linear fit on top of the scatter plot. Calculate (or output) the mean squared error and R-squared values for your fit

# %%
X = features_df[['bmi']]
y = features_df['target']

# %%
reg = LinearRegression().fit(X, y)

# %%
reg.coef_
# Out:
# array([949.43526038])

# %%
reg.intercept_
# Out:
# 152.1334841628967

# %%
ytrain = reg.intercept_ + reg.coef_ * X

# %%
plt.plot(X,y,'ro',X,ytrain,'b-');

# %%
mean_squared_error(y, ytrain)
# Out:
# 3890.4565854612724

# %%
r2_score(y, ytrain)
# Out:
# 0.3439237602253803

# %% [markdown]
# #### Try doing linear regression with another variable and check how the new fit's mean squared error and R-squared values change.

# %%
X1 = features_df[['bp']]
y1 = features_df['target']

# %%
reg = LinearRegression().fit(X1, y1)

# %%
reg.coef_
# Out:
# array([714.7416437])

# %%
reg.intercept_
# Out:
# 152.13348416289585

# %%
ytrain = reg.intercept_ + reg.coef_ * X

# %%
plt.plot(X,y,'ro',X,ytrain,'b-');

# %%
mean_squared_error(y, ytrain)
# Out:
# 4015.0744445341

# %%
r2_score(y, ytrain)
# Out:
# 0.322908536281024

# %% [markdown]
# When I did linear regression with the variable 'bp', which has a lower correlation with the target values, the mean squared error increased and the R-squared value decreased.
